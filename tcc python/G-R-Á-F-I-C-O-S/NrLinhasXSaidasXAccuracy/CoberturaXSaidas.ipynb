# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
headers = ['Case','Linhas','Saidas','Acc']
df = pd.read_csv('Nrlinhas-VS-accuracy.csv', encoding='utf8', names=headers)


df["Cobertura"] = df['Linhas'] / np.exp(df['Saidas'])
df = df.sort_values(by=['Cobertura'])

x = list(range(len(df['Case'])))
#data1 = np.log(df['Linhas'])
data1 = df['Cobertura']
data2 = df['Saidas']
data3 = df['Acc']

my_dpi=250
fig = plt.figure(figsize=(1200/my_dpi, 800/my_dpi), dpi=my_dpi)
fig, ax1 = plt.subplots()

plt.minorticks_on()
plt.grid(which='major', linestyle='--')
plt.grid(which='minor', linestyle=':')

ax1.set_ylabel('Cobertura', color='g') #verde
ax1.tick_params('y', colors='g')

lns1 = plt.plot(x,data1, 'go', label='Cobertura lns1') # green bolinha
lns1 = plt.plot(x,data1, 'k:', color='orange')


ax2 = ax1.twinx()

lns2 = ax2.plot(x,data2, 'r^' , label='Saídas') # red triangulo 
lns2 = ax2.plot(x,data2, 'k--', color='blue')  # linha tracejada azul
#ax3 = ax1.twinx()
#lns3 = ax3.plot(x,data2, 'm*' , label='saidas') 
#lns3 = ax1.plot(x,data2, 'm*' , label='Saidas lns3')
#lns3 = ax1.plot(x,data2, 'k--', color='blue')

ax2.set_ylabel('Saidas', color='r')
ax2.tick_params('y', colors='r')


ax1.legend(loc='upper left', bbox_to_anchor=(0.0, -0.30), shadow=False, ncol=5)
ax2.legend(loc='upper left', bbox_to_anchor=(0.0, -0.15), shadow=False, ncol=5)
fig.savefig('CoberturaVS_saidas.png',dpi=100)
print(df)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in exp
#   if __name__ == '__main__':
#     Case  Linhas  Saidas     Acc      Cobertura
# 73    74      53     914   24.03   0.000000e+00
# 17    18       8    2474   24.96   0.000000e+00
# 25    26      13    2474   24.98   0.000000e+00
# 30    31       9    2474   25.01   0.000000e+00
# 13    14       6    2726    0.25   0.000000e+00
# 12    13       7    2726    0.25   0.000000e+00
# 11    12      10    5397   24.79   0.000000e+00
# 10    11       6    5397   24.79   0.000000e+00
# 18    19      11    2474   24.99   0.000000e+00
# 9     10      10    5397   24.83   0.000000e+00
# 31    32      13    2474   24.98   0.000000e+00
# 32    33       7    2726    0.33   0.000000e+00
# 33    34       6    2726    0.48   0.000000e+00
# 34    35      33     914   24.07   0.000000e+00
# 35    36      52     914   24.03   0.000000e+00
# 72    73      33     914   24.03   0.000000e+00
# 8      9       6    5397   24.86   0.000000e+00
# 24    25       9    2474   25.00   0.000000e+00
# 28    29       6     256    4.56  3.969757e-111
# 1      2       6     256    4.56  3.969757e-111
# 0      1       8     256    4.27  5.293009e-111
# 29    30      11     256   26.96  7.277887e-111
# 26    27      32     129   83.44   3.028041e-55
# 58    59      37     129   83.44   3.501173e-55
# 59    60      37     129   82.56   3.501173e-55
# 27    28      38     129   83.44   3.595799e-55
# 2      3      14     128   34.19   3.601093e-55
# 7      8      14     128   34.19   3.601093e-55
# 3      4      15     128   34.32   3.858314e-55
# 6      7      18     128   34.21   4.629977e-55
# ..   ...     ...     ...     ...            ...
# 37    38       4      10    6.67   1.815997e-04
# 36    37       4      10   16.67   1.815997e-04
# 41    42      19      10    9.53   8.625987e-04
# 51    52      21      10   10.00   9.533985e-04
# 40    41      23      10   10.05   1.044198e-03
# 50    51      24      10    9.16   1.089598e-03
# 48    49     109      10   10.84   4.948592e-03
# 49    50     245      10   10.68   1.112298e-02
# 46    47     121       5  100.00   8.152916e-01
# 47    48     190       5  100.00   1.280210e+00
# 45    46    1533       7   82.26   1.397915e+00
# 44    45    1841       7   82.18   1.678775e+00
# 52    53      40       2  100.00   5.413411e+00
# 53    54      48       2  100.00   6.496094e+00
# 42    43      56       2   47.37   7.578776e+00
# 43    44     102       1  100.00   3.752370e+01
# 69    70   38843       3  100.00   1.933879e+03
# 68    69   49160       3  100.00   2.447532e+03
# 38    39   26902       2  100.00   3.640790e+03
# 39    40   26913       2  100.00   3.642278e+03
# 16    17   20211       1  100.00   7.435211e+03
# 14    15   42735       1  100.00   1.572133e+04
# 56    57   42766       1  100.00   1.573273e+04
# 19    20  118904       2  100.00   1.609191e+04
# 15    16   45978       1  100.00   1.691436e+04
# 57    58   47240       1  100.00   1.737862e+04
# 23    24  136569       2  100.00   1.848260e+04
# 21    22  118963       1  100.00   4.376404e+04
# 22    23  135967       1  100.00   5.001946e+04
# 20    21  136321       1  100.00   5.014969e+04
#
# [74 rows x 5 columns]
